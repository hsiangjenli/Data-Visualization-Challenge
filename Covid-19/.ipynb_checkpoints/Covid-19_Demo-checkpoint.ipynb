# %% [markdown]
# ![](Images/Cover.png)

# %% [markdown]
# 1. [直轄市、縣市界線(TWD97經緯度)](https://data.gov.tw/dataset/7442)
# 1. [鄉鎮市區界線(TWD97經緯度)](https://data.gov.tw/dataset/7441)
# 1. [Three Ways to Plot Choropleth Map Using Python](https://medium.com/geekculture/three-ways-to-plot-choropleth-map-using-python-f53799a3e623)
# 1. [Download GADM data (version 3.6)](https://gadm.org/download_country_v3.html)
# 1. [Python 練習: 以地圖顯示癌症死因資料(II)](http://viml.nchc.org.tw/blog/paper_info.php?CLASS_ID=1&SUB_ID=1&PAPER_ID=687)
# 1. [Python 地圖視覺化 - 使用 Folium](https://blog.yeshuanova.com/2017/10/python-visulization-folium/)
# 1. [install geopandas](https://geopandas.org/getting_started/install.html)
# 1. [Pandas Merging 101](https://stackoverflow.com/questions/53645882/pandas-merging-101)

# %% [markdown]
# # **Covid-19 Taiwan**

# %% [markdown]
# ## **Install requirements**

# %%
# !python --version
# Out:
# Python 3.8.8

# %%
from helper import *
import os

for n in os.listdir("requirements"): print(n)
# Out:
# Fiona-1.8.20-cp38-cp38-win_amd64.whl
# GDAL-3.3.3-cp38-cp38-win_amd64.whl
# geopandas-0.10.2-py2.py3-none-any.whl
# pyproj-3.2.1-cp38-cp38-win_amd64.whl
# Shapely-1.8.0-cp38-cp38-win_amd64.whl

# %%
# !pip install Requirements/GDAL-3.3.3-cp38-cp38-win_amd64.whl
# !pip install Requirements/pyproj-3.2.1-cp38-cp38-win_amd64.whl
# !pip install Requirements/Fiona-1.8.20-cp38-cp38-win_amd64.whl
# !pip install Requirements/Shapely-1.8.0-cp38-cp38-win_amd64.whl
# !pip install Requirements/geopandas-0.10.2-py2.py3-none-any.whl
# Out:
# Processing d:\python\data visualization\covid-19\requirements\gdal-3.3.3-cp38-cp38-win_amd64.whl
# GDAL is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# Processing d:\python\data visualization\covid-19\requirements\pyproj-3.2.1-cp38-cp38-win_amd64.whl
# ...
# pyproj is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# Processing d:\python\data visualization\covid-19\requirements\fiona-1.8.20-cp38-cp38-win_amd64.whl
# ...
# Fiona is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# Processing d:\python\data visualization\covid-19\requirements\shapely-1.8.0-cp38-cp38-win_amd64.whl
# Shapely is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
# ...

# %% [markdown]
# ## **Import the Dataset**

# %% [markdown]
# ### **Covid-19**

# %%
df = get_covid19_data()
df.head(3)
# Out:
#         確定病名      個案研判日  縣市  鄉鎮 性別 是否為境外移入    年齡層  確定病例數
# 0  嚴重特殊傳染性肺炎 2020-01-22  空值  空值  女       是  55-59      1
# 1  嚴重特殊傳染性肺炎 2020-01-24  空值  空值  女       是  50-54      1
# 2  嚴重特殊傳染性肺炎 2020-01-24  空值  空值  男       是  55-59      1

# %% [markdown]
# ### **County**

# %%
cshp = Shape.County()
cshp.head(3)
# Out:
#            COUNTYID COUNTYCODE          COUNTYENG  \
# COUNTYNAME
# 連江縣               Z      09007  Lienchiang County
# 宜蘭縣               G      10002       Yilan County
# 彰化縣               N      10007    Changhua County
#
#                                                      geometry
# COUNTYNAME
# 連江縣         MULTIPOLYGON (((119.96445 25.94552, 119.96427 ...
# 宜蘭縣         MULTIPOLYGON (((121.95971 24.84494, 121.96064 ...
# 彰化縣         POLYGON ((120.45655 24.20719, 120.48589 24.197...

# %% [markdown]
# ### **Town**

# %%
tshp = Shape.Town()
tshp.head(3)
# Out:
#          TOWNID  TOWNCODE COUNTYNAME             TOWNENG COUNTYID COUNTYCODE  \
# TOWNNAME
# 成功鎮         V02  10014020        臺東縣  Chenggong Township        V      10014
# 佳冬鄉         T21  10013210        屏東縣    Jiadong Township        T      10013
# 麥寮鄉         P13  10009130        雲林縣    Mailiao Township        P      10009
#
#                                                    geometry
# TOWNNAME
# 成功鎮       POLYGON ((121.40982 23.21369, 121.40984 23.213...
# 佳冬鄉       POLYGON ((120.54846 22.46067, 120.54853 22.460...
# 麥寮鄉       POLYGON ((120.30198 23.81625, 120.30197 23.815...

# %% [markdown]
# ## **Plot**

# %% [markdown]
# ### **Normal**

# %%
p1 = plot(data=cshp, plot_type='normal', column=None, cmap='Wistia', file_name='Taiwan_COUNTY')
p2 = plot(data=tshp, plot_type='normal', column=None, cmap='Wistia', file_name='Taiwan_TOWN')

# %%
crop(p1)

# %%
crop(p2)

# %% [markdown]
# ### **Heatmap**
